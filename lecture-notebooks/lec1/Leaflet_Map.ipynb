# %% [markdown]
# # Leaflet Activity

# %% [markdown]
# Find the coordinates for our classroom!
#
# Open up [Google Maps](https://www.google.com/maps), find the location, then right-click (or double-tap) to copy the latitude and longitude.

# %% [markdown]
# ### Assigning a variable

# %%
# vector

# %%
# named vector

# %%
# list

# %%
# Libraries have more variables and things we can use to create more containers
# A tibble is a container for tabular data
library(tibble) 

T <- tibble(
  lat   = 38.89859285082495,
  lng   = -77.0461995467069,
  label = "Bell Hall"
)

# %% [markdown]
# ### Access a value

# %%
# Inside a typical vector

# %%
# Inside a named vector

# %%
# Inside a list

# %%
library(readr)
T <- read_csv('Bell_coords.csv')
T

# %%
library(leaflet)

leaflet() |> 
  addTiles() |>   
  addMarkers(lat = , lng = , label = )

# %% [markdown]
# Leaflet guide: [R Charts](https://r-charts.com/spatial/interactive-maps-leaflet/)
#
# [Official documentation](https://cran.r-project.org/web/packages/leaflet/index.html)

# %%
#For those who have used functions in programming before, this is the same thing as
addMarkers(addTiles(leaflet()), lat = , lng = , label = )
